# %% [markdown]
# <a href="https://colab.research.google.com/github/awjans/CopilotForPRsAdoption/blob/main/scripts/AIDev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Collection/Cleaning Overview
# 1. **PR identification**
#    * Queried GitHub via GraphQL for PRs whose description contained the phrase **“Generated by Copilot”** or any of the marker tags:
#
#      * `copilot:summary`
#      * `copilot:walkthrough`
#      * `copilot:poem`
#      * `copilot:all`
#
# 2. **Scope**
#    * Collected **18,256 PRs** from **146 early-adopter repositories** during **March 2023 – August 2023**.
#
# 3. **Control set**
#    * For the same repositories, gathered **54,188 PRs** that did **not** contain any Copilot marker.
#    * These served as the **untreated (control) group** for the **RQ2 comparison**.
#
# 4. **Bot filtering**
#    * Removed PRs and comments authored by bots using the **high-precision method** of **Golzadeh et al. (2022)**, which included:
#      * (i) Usernames ending with “bot”
#      * (ii) A curated list of **527 known bot accounts**
#
# 5. **Revision extraction (RQ3)**
#    * From the **18,256 Copilot-generated PRs**, retrieved the full **edit history** of PR descriptions.
#    * Identified **1,437 revisions** where developers **edited the AI-suggested content**.

# %%
import asyncio
import matplotlib.pyplot as plt
import nest_asyncio
import numpy as np
import os
import pandas as pd
import requests
import seaborn as sns
import datetime

from dateutil import parser
from google.colab import userdata
from urllib.parse import urlparse

# %% [markdown]
# # **First**, We need to define the URLs of the AIDev Parquet Files that we are intersted in.

# %%
pull_request_file_url = 'https://huggingface.co/datasets/hao-li/AIDev/resolve/main/pull_request.parquet'
pr_comments_file_url = 'https://huggingface.co/datasets/hao-li/AIDev/resolve/main/pr_comments.parquet'
pr_commits_file_url = 'https://huggingface.co/datasets/hao-li/AIDev/resolve/main/pr_commits.parquet'
pr_commit_details_file_url = 'https://huggingface.co/datasets/hao-li/AIDev/resolve/main/pr_commit_details.parquet'
pr_reviews_file_url = 'https://huggingface.co/datasets/hao-li/AIDev/resolve/main/pr_reviews.parquet'
pr_review_comments_file_url = 'https://huggingface.co/datasets/hao-li/AIDev/resolve/main/pr_review_comments.parquet'
pr_task_type_file_url = 'https://huggingface.co/datasets/hao-li/AIDev/resolve/main/pr_task_type.parquet'
repository_file_url = 'https://huggingface.co/datasets/hao-li/AIDev/resolve/main/repository.parquet'
user_file_url = 'https://huggingface.co/datasets/hao-li/AIDev/resolve/main/user.parquet'

# %%
"""
Load the Parquet file into a Pandas DataFrame from the file URL.
"""
def load_data(url: str):
  import pandas as pd # Import pandas inside the function
  try:
    # For Parquet files:
    df = pd.read_parquet(url)

    return df
  except Exception as e:
      print(f"Error loading data: {e}")
      print("Please ensure the URL is correct and the file is publicly accessible.")
      return None # Return None in case of an error

# %%
nest_asyncio.apply()

GH_TOKEN = os.environ.get('GITHUB_TOKEN', userdata.get('GITHUB_TOKEN'))

async def get_repo_data(repo_url: str):
    # Make the Request
    print(f'Requesting: {repo_url}')
    response = requests.get(repo_url, headers={'Authorization': f'token {GH_TOKEN}'})
    response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
    # Process the JSON response
    return response.json()


def get_repo_created_at(repo_url: str):
    """
    Get the Repository Created At timestamp for the Repo from GitHub the API call.

    Args:
        repo_url: The GitHub API repository URL.

    Returns:
        The created_at timestamp if successful, None otherwise.
    """
    try:
        task = asyncio.create_task(get_repo_data(repo_url))
        event_loop = asyncio.get_running_loop()
        if event_loop.is_running():
          data = event_loop.run_until_complete(task)
        else:
          data = asyncio.run(task)

        # Extract the createdAt value
        created_at = data['created_at']
        print(f"Repo: {repo_url}; Created At: {created_at}")

        if created_at:
            return pd.to_datetime(created_at)
        else:
            raise Exception(f"Error: Could not retrieve createdAt for {repo_url}. Response data: {data}")

    except requests.exceptions.RequestException as e:
        print(f"Error during GitHub API request for {repo_url}: {e}")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# %% [markdown]
# # **Second**, We need to load the data from the URLs

# %%
pull_request = load_data(pull_request_file_url)
pr_comments = load_data(pr_comments_file_url)
pr_commits = load_data(pr_commits_file_url)
pr_commit_details = load_data(pr_commit_details_file_url)
pr_reviews = load_data(pr_reviews_file_url)
pr_review_comments = load_data(pr_review_comments_file_url)
pr_task_type = load_data(pr_task_type_file_url)
repository = load_data(repository_file_url)
user = load_data(user_file_url)

# %% [markdown]
# ## Create a Copy of Pull_Requests
#
# Remove the Open Pull Requests

# %%
metrics = pull_request.copy()
repos = repository.copy()

# Remove Open Pull Requests (closed_at is None)
print(f"Number of Pull Requests: {len(metrics)}")
metrics = metrics[metrics['closed_at'].notna()]
print(f"Number of Pull Requests: {len(metrics)}")

# Convert Timestamps
metrics['created_at'] = pd.to_datetime(metrics['created_at'])
metrics['closed_at'] = pd.to_datetime(metrics['closed_at'])

# Remove Repositories that do not have a Pull Request
print(f"Number of Repositories: {len(repos)}")
repos = repos[repos['id'].isin(metrics['repo_id'])]
print(f"Number of Repositories: {len(repos)}")
repos['created_at'] = repos.apply(lambda row: get_repo_created_at(row['url']), axis=1)
repos = repos.dropna(subset=['created_at'])
print(f"Number of Repositories: {len(repos)}")
# Out:
# Number of Pull Requests: 33596
# Number of Pull Requests: 31284
# Number of Repositories: 2807
# Number of Repositories: 2404
# Requesting: https://api.github.com/repos/kizuna-ai-lab/sokuji
# Repo: https://api.github.com/repos/kizuna-ai-lab/sokuji; Created At: 2025-04-14T15:58:15Z
# Requesting: https://api.github.com/repos/freenet/freenet-core
# Repo: https://api.github.com/repos/freenet/freenet-core; Created At: 2021-07-16T13:19:06Z
# Requesting: https://api.github.com/repos/vexxhost/atmosphere
# Repo: https://api.github.com/repos/vexxhost/atmosphere; Created At: 2022-08-23T23:21:09Z
# Requesting: https://api.github.com/repos/JonasKruckenberg/k23
# Repo: https://api.github.com/repos/JonasKruckenberg/k23; Created At: 2023-10-12T10:28:02Z
# Requesting: https://api.github.com/repos/JuliaLang/julia
# Repo: https://api.github.com/repos/JuliaLang/julia; Created At: 2011-04-21T07:01:50Z
# Requesting: https://api.github.com/repos/artsy/force
# Repo: https://api.github.com/repos/artsy/force; Created At: 2014-08-12T18:14:34Z
# Requesting: https://api.github.com/repos/groue/GRDB.swift
# Repo: https://api.github.com/repos/groue/GRDB.swift; Created At: 2015-06-30T11:17:06Z
# Requesting: https://api.github.com/repos/ml-explore/mlx-examples
# Repo: https://api.github.com/repos/ml-explore/mlx-examples; Created At: 2023-11-28T23:37:49Z
# Requesting: https://api.github.com/repos/wataru-maeda/react-native-boilerplate
# Repo: https://api.github.com/repos/wataru-maeda/react-native-boilerplate; Created At: 2018-06-02T03:27:41Z
# Requesting: https://api.github.com/repos/Shelf-nu/shelf.nu
# Repo: https://api.github.com/repos/Shelf-nu/shelf.nu; Created At: 2023-02-10T16:04:12Z
# Requesting: https://api.github.com/repos/badlogic/lemmy
# Repo: https://api.github.com/repos/badlogic/lemmy; Created At: 2025-05-23T14:33:46Z
# Requesting: https://api.github.com/repos/Effect-TS/effect-smol
# Repo: https://api.github.com/repos/Effect-TS/effect-smol; Created At: 2024-12-10T02:55:19Z
# Requesting: https://api.github.com/repos/JuliaLang/Pkg.jl
# Repo: https://api.github.com/repos/JuliaLang/Pkg.jl; Created At: 2017-02-17T21:51:01Z
# Requesting: https://api.github.com/repos/compiler-explorer/infra
# Repo: https://api.github.com/repos/compiler-explorer/infra; Created At: 2014-04-16T15:05:13Z
# Requesting: https://api.github.com/repos/giselles-ai/giselle
# Repo: https://api.github.com/repos/giselles-ai/giselle; Created At: 2024-08-21T02:40:46Z
# Requesting: https://api.github.com/repos/TracecatHQ/tracecat
# Repo: https://api.github.com/repos/TracecatHQ/tracecat; Created At: 2024-02-27T06:48:32Z
# Requesting: https://api.github.com/repos/Akira-Papa/Claude-Code-Communication
# Repo: https://api.github.com/repos/Akira-Papa/Claude-Code-Communication; Created At: 2025-06-10T19:17:35Z
# Requesting: https://api.github.com/repos/mendableai/firecrawl
# Repo: https://api.github.com/repos/mendableai/firecrawl; Created At: 2024-04-15T21:02:29Z
# Requesting: https://api.github.com/repos/modelcontextprotocol/servers
# Repo: https://api.github.com/repos/modelcontextprotocol/servers; Created At: 2024-11-19T01:10:17Z
# Requesting: https://api.github.com/repos/firezone/firezone
# Repo: https://api.github.com/repos/firezone/firezone; Created At: 2020-04-22T04:05:12Z
# Requesting: https://api.github.com/repos/BeehiveInnovations/zen-mcp-server
# Repo: https://api.github.com/repos/BeehiveInnovations/zen-mcp-server; Created At: 2025-06-08T15:36:50Z
# Requesting: https://api.github.com/repos/vllm-project/vllm
# Repo: https://api.github.com/repos/vllm-project/vllm; Created At: 2023-02-09T11:23:20Z
# Requesting: https://api.github.com/repos/CoderGamester/mcp-unity
# Repo: https://api.github.com/repos/CoderGamester/mcp-unity; Created At: 2025-03-13T20:41:25Z
# Requesting: https://api.github.com/repos/mlflow/mlflow
# Repo: https://api.github.com/repos/mlflow/mlflow; Created At: 2018-06-05T16:05:58Z
# Requesting: https://api.github.com/repos/wolfi-dev/os
# Repo: https://api.github.com/repos/wolfi-dev/os; Created At: 2022-09-07T19:46:09Z
# Requesting: https://api.github.com/repos/ithacaxyz/porto
# Repo: https://api.github.com/repos/ithacaxyz/porto; Created At: 2024-11-12T01:55:23Z
# Requesting: https://api.github.com/repos/zenml-io/zenml
# Repo: https://api.github.com/repos/zenml-io/zenml; Created At: 2020-11-19T09:25:46Z
# Requesting: https://api.github.com/repos/cockroachdb/cockroach
# Repo: https://api.github.com/repos/cockroachdb/cockroach; Created At: 2014-02-06T00:18:47Z
# Requesting: https://api.github.com/repos/Deepractice/PromptX
# Repo: https://api.github.com/repos/Deepractice/PromptX; Created At: 2025-05-13T04:17:28Z
# Requesting: https://api.github.com/repos/smtg-ai/claude-squad
# Repo: https://api.github.com/repos/smtg-ai/claude-squad; Created At: 2025-03-09T20:00:41Z
# Requesting: https://api.github.com/repos/mizchi/similarity
# Repo: https://api.github.com/repos/mizchi/similarity; Created At: 2025-06-16T15:34:41Z
# Requesting: https://api.github.com/repos/tphakala/birdnet-go
# Repo: https://api.github.com/repos/tphakala/birdnet-go; Created At: 2023-10-20T15:51:19Z
# Requesting: https://api.github.com/repos/TensorBlock/awesome-mcp-servers
# Repo: https://api.github.com/repos/TensorBlock/awesome-mcp-servers; Created At: 2025-04-04T04:23:33Z
# Requesting: https://api.github.com/repos/allenai/open-instruct
# Repo: https://api.github.com/repos/allenai/open-instruct; Created At: 2023-06-09T16:50:38Z
# Requesting: https://api.github.com/repos/bufbuild/buf
# Repo: https://api.github.com/repos/bufbuild/buf; Created At: 2019-10-03T00:09:57Z
# Requesting: https://api.github.com/repos/rinadelph/Agent-MCP
# Repo: https://api.github.com/repos/rinadelph/Agent-MCP; Created At: 2025-05-13T15:40:10Z
# Requesting: https://api.github.com/repos/haasonsaas/ocode
# Repo: https://api.github.com/repos/haasonsaas/ocode; Created At: 2025-05-27T00:03:55Z
# Requesting: https://api.github.com/repos/jamesrochabrun/SwiftAnthropic
# Repo: https://api.github.com/repos/jamesrochabrun/SwiftAnthropic; Created At: 2024-01-29T07:43:03Z
# Requesting: https://api.github.com/repos/LLFourn/secp256kfun
# Repo: https://api.github.com/repos/LLFourn/secp256kfun; Created At: 2020-02-27T07:59:07Z
# Requesting: https://api.github.com/repos/basicmachines-co/basic-memory
# Repo: https://api.github.com/repos/basicmachines-co/basic-memory; Created At: 2024-12-02T22:40:43Z
# Requesting: https://api.github.com/repos/FinAegis/core-banking-prototype-laravel
# Repo: https://api.github.com/repos/FinAegis/core-banking-prototype-laravel; Created At: 2024-08-14T16:54:26Z
# Requesting: https://api.github.com/repos/stepfunc/dnp3
# Repo: https://api.github.com/repos/stepfunc/dnp3; Created At: 2020-03-09T02:26:57Z
# Requesting: https://api.github.com/repos/ryoppippi/ccusage
# Repo: https://api.github.com/repos/ryoppippi/ccusage; Created At: 2025-05-29T16:56:50Z
# Requesting: https://api.github.com/repos/busser/tfautomv
# Repo: https://api.github.com/repos/busser/tfautomv; Created At: 2022-04-16T10:38:07Z
# Requesting: https://api.github.com/repos/modelcontextprotocol/inspector
# Repo: https://api.github.com/repos/modelcontextprotocol/inspector; Created At: 2024-10-03T21:47:42Z
# Requesting: https://api.github.com/repos/brentyi/jaxls
# Repo: https://api.github.com/repos/brentyi/jaxls; Created At: 2020-11-16T09:15:02Z
# Requesting: https://api.github.com/repos/d-kuro/gwq
# Repo: https://api.github.com/repos/d-kuro/gwq; Created At: 2025-05-26T10:48:05Z
# Requesting: https://api.github.com/repos/JoshuaC215/agent-service-toolkit
# Repo: https://api.github.com/repos/JoshuaC215/agent-service-toolkit; Created At: 2024-08-04T23:13:44Z
# Requesting: https://api.github.com/repos/facebook/idb
# Repo: https://api.github.com/repos/facebook/idb; Created At: 2015-09-03T16:25:17Z
# Requesting: https://api.github.com/repos/danny-avila/LibreChat
# Repo: https://api.github.com/repos/danny-avila/LibreChat; Created At: 2023-02-12T01:06:52Z
# Requesting: https://api.github.com/repos/codexu/note-gen
# Repo: https://api.github.com/repos/codexu/note-gen; Created At: 2024-08-06T05:20:16Z
# Requesting: https://api.github.com/repos/spylang/spy
# Repo: https://api.github.com/repos/spylang/spy; Created At: 2023-05-19T14:23:12Z
# Requesting: https://api.github.com/repos/evmts/tevm-monorepo
# Repo: https://api.github.com/repos/evmts/tevm-monorepo; Created At: 2023-02-14T06:21:49Z
# Requesting: https://api.github.com/repos/jlowin/fastmcp
# Repo: https://api.github.com/repos/jlowin/fastmcp; Created At: 2024-11-30T01:47:40Z
# Requesting: https://api.github.com/repos/JuliaSymbolics/Symbolics.jl
# Repo: https://api.github.com/repos/JuliaSymbolics/Symbolics.jl; Created At: 2021-01-21T14:12:03Z
# Requesting: https://api.github.com/repos/anyproto/anytype-swift
# Repo: https://api.github.com/repos/anyproto/anytype-swift; Created At: 2023-05-26T08:13:01Z
# Requesting: https://api.github.com/repos/wheels-dev/wheels
# Repo: https://api.github.com/repos/wheels-dev/wheels; Created At: 2011-01-13T11:31:48Z
# Requesting: https://api.github.com/repos/belladoreai/llama3-tokenizer-js
# Repo: https://api.github.com/repos/belladoreai/llama3-tokenizer-js; Created At: 2024-04-19T12:35:01Z
# Requesting: https://api.github.com/repos/wvlet/wvlet
# Repo: https://api.github.com/repos/wvlet/wvlet; Created At: 2024-08-23T23:21:17Z
# Requesting: https://api.github.com/repos/joshukraine/dotfiles
# Repo: https://api.github.com/repos/joshukraine/dotfiles; Created At: 2014-07-03T11:53:41Z
# Requesting: https://api.github.com/repos/mrwadams/stride-gpt
# Repo: https://api.github.com/repos/mrwadams/stride-gpt; Created At: 2023-04-10T20:46:06Z
# Requesting: https://api.github.com/repos/onetimesecret/onetimesecret
# Repo: https://api.github.com/repos/onetimesecret/onetimesecret; Created At: 2013-01-30T11:21:31Z
# Requesting: https://api.github.com/repos/razimantv/mazegenerator
# Repo: https://api.github.com/repos/razimantv/mazegenerator; Created At: 2013-05-25T16:24:56Z
# Requesting: https://api.github.com/repos/numbagg/numbagg
# Repo: https://api.github.com/repos/numbagg/numbagg; Created At: 2014-10-21T04:10:26Z
# Requesting: https://api.github.com/repos/oven-sh/bun
# Repo: https://api.github.com/repos/oven-sh/bun; Created At: 2021-04-14T00:48:17Z
# Requesting: https://api.github.com/repos/SuperClaude-Org/SuperClaude_Framework
# Repo: https://api.github.com/repos/SuperClaude-Org/SuperClaude_Framework; Created At: 2025-06-22T12:03:53Z
# Requesting: https://api.github.com/repos/ar-io/ar-io-node
# Repo: https://api.github.com/repos/ar-io/ar-io-node; Created At: 2022-04-12T01:42:50Z
# Requesting: https://api.github.com/repos/mastra-ai/mastra
# Repo: https://api.github.com/repos/mastra-ai/mastra; Created At: 2024-08-06T20:44:31Z
# Requesting: https://api.github.com/repos/aws-samples/generative-ai-use-cases
# Repo: https://api.github.com/repos/aws-samples/generative-ai-use-cases; Created At: 2023-08-17T02:08:52Z
# Requesting: https://api.github.com/repos/siteboon/claudecodeui
# Repo: https://api.github.com/repos/siteboon/claudecodeui; Created At: 2025-06-25T12:51:12Z
# Requesting: https://api.github.com/repos/dotCMS/core
# Repo: https://api.github.com/repos/dotCMS/core; Created At: 2012-03-15T15:24:14Z
# Requesting: https://api.github.com/repos/typedef-ai/fenic
# Repo: https://api.github.com/repos/typedef-ai/fenic; Created At: 2025-06-16T20:16:50Z
# Requesting: https://api.github.com/repos/goodjoblife/GoodJobShare
# Repo: https://api.github.com/repos/goodjoblife/GoodJobShare; Created At: 2017-01-14T16:33:20Z
# Requesting: https://api.github.com/repos/monarch-initiative/mondo
# Repo: https://api.github.com/repos/monarch-initiative/mondo; Created At: 2017-09-20T16:46:09Z
# Requesting: https://api.github.com/repos/proximafusion/vmecpp
# Repo: https://api.github.com/repos/proximafusion/vmecpp; Created At: 2024-11-12T22:51:16Z
# Requesting: https://api.github.com/repos/anthropics/claude-code
# Repo: https://api.github.com/repos/anthropics/claude-code; Created At: 2025-02-22T17:41:21Z
# Requesting: https://api.github.com/repos/kbwo/ccmanager
# Repo: https://api.github.com/repos/kbwo/ccmanager; Created At: 2025-06-07T12:41:22Z
# Requesting: https://api.github.com/repos/osmosis-labs/osmosis
# Repo: https://api.github.com/repos/osmosis-labs/osmosis; Created At: 2020-10-17T09:24:41Z
# Requesting: https://api.github.com/repos/Shopify/roast
# Repo: https://api.github.com/repos/Shopify/roast; Created At: 2025-04-09T21:05:31Z
# Requesting: https://api.github.com/repos/nrwl/nx
# Repo: https://api.github.com/repos/nrwl/nx; Created At: 2017-08-11T18:50:23Z
# Requesting: https://api.github.com/repos/pannous/wasp
# Repo: https://api.github.com/repos/pannous/wasp; Created At: 2018-03-18T13:52:03Z
# Requesting: https://api.github.com/repos/dai-motoki/haconiwa
# Repo: https://api.github.com/repos/dai-motoki/haconiwa; Created At: 2025-06-07T04:15:04Z
# Requesting: https://api.github.com/repos/pdm-project/pdm
# Repo: https://api.github.com/repos/pdm-project/pdm; Created At: 2019-12-27T03:50:57Z
# Requesting: https://api.github.com/repos/ruvnet/ruv-FANN
# Repo: https://api.github.com/repos/ruvnet/ruv-FANN; Created At: 2025-06-26T20:38:15Z
# Requesting: https://api.github.com/repos/sst/opencode
# Repo: https://api.github.com/repos/sst/opencode; Created At: 2025-04-30T20:08:00Z
# Requesting: https://api.github.com/repos/tier4/scenario_simulator_v2
# Repo: https://api.github.com/repos/tier4/scenario_simulator_v2; Created At: 2020-08-28T06:18:18Z
# Requesting: https://api.github.com/repos/intellectronica/ruler
# Repo: https://api.github.com/repos/intellectronica/ruler; Created At: 2025-05-20T08:22:59Z
# Requesting: https://api.github.com/repos/eyaltoledano/claude-task-master
# Repo: https://api.github.com/repos/eyaltoledano/claude-task-master; Created At: 2025-03-04T18:54:54Z
# Requesting: https://api.github.com/repos/Deep-Learning-Profiling-Tools/triton-viz
# Repo: https://api.github.com/repos/Deep-Learning-Profiling-Tools/triton-viz; Created At: 2024-02-12T02:02:10Z
# Requesting: https://api.github.com/repos/airbytehq/airbyte
# Repo: https://api.github.com/repos/airbytehq/airbyte; Created At: 2020-07-27T23:55:54Z
# Requesting: https://api.github.com/repos/kingstinct/react-native-healthkit
# Repo: https://api.github.com/repos/kingstinct/react-native-healthkit; Created At: 2020-06-26T22:40:28Z
# Requesting: https://api.github.com/repos/bayesianbandits/bayesianbandits
# Repo: https://api.github.com/repos/bayesianbandits/bayesianbandits; Created At: 2023-02-14T00:34:59Z
# Requesting: https://api.github.com/repos/BerriAI/litellm
# Repo: https://api.github.com/repos/BerriAI/litellm; Created At: 2023-07-27T00:09:52Z
# Requesting: https://api.github.com/repos/RevenueCat/purchases-ios
# Repo: https://api.github.com/repos/RevenueCat/purchases-ios; Created At: 2017-10-23T20:23:47Z
# Requesting: https://api.github.com/repos/shopware/shopware
# Repo: https://api.github.com/repos/shopware/shopware; Created At: 2018-05-03T13:00:31Z
# Requesting: https://api.github.com/repos/sam-goodwin/alchemy
# Repo: https://api.github.com/repos/sam-goodwin/alchemy; Created At: 2025-01-17T02:06:40Z
# Requesting: https://api.github.com/repos/quarylabs/sqruff
# Repo: https://api.github.com/repos/quarylabs/sqruff; Created At: 2023-02-13T19:36:25Z
# Requesting: https://api.github.com/repos/recallnet/js-recall
# Repo: https://api.github.com/repos/recallnet/js-recall; Created At: 2025-01-08T21:08:21Z
# Requesting: https://api.github.com/repos/567-labs/kura
# Repo: https://api.github.com/repos/567-labs/kura; Created At: 2025-01-04T16:12:18Z
# Requesting: https://api.github.com/repos/pyvista/pyvista
# Repo: https://api.github.com/repos/pyvista/pyvista; Created At: 2017-05-31T18:01:42Z
# Requesting: https://api.github.com/repos/INCATools/ontology-access-kit
# Repo: https://api.github.com/repos/INCATools/ontology-access-kit; Created At: 2022-03-28T15:50:45Z
# Requesting: https://api.github.com/repos/juspay/hyperswitch
# Repo: https://api.github.com/repos/juspay/hyperswitch; Created At: 2022-10-17T11:18:28Z
# Requesting: https://api.github.com/repos/pytorch/pytorch
# Repo: https://api.github.com/repos/pytorch/pytorch; Created At: 2016-08-13T05:26:41Z
# Requesting: https://api.github.com/repos/MervinPraison/PraisonAI
# Repo: https://api.github.com/repos/MervinPraison/PraisonAI; Created At: 2024-03-19T16:45:25Z
# Requesting: https://api.github.com/repos/modelcontextprotocol/typescript-sdk
# Repo: https://api.github.com/repos/modelcontextprotocol/typescript-sdk; Created At: 2024-09-24T20:45:31Z
# Requesting: https://api.github.com/repos/fireship-io/flamethrower
# Repo: https://api.github.com/repos/fireship-io/flamethrower; Created At: 2022-08-16T15:52:56Z
# Requesting: https://api.github.com/repos/mautic/mautic
# Repo: https://api.github.com/repos/mautic/mautic; Created At: 2013-08-19T00:36:28Z
# Requesting: https://api.github.com/repos/deeeed/expo-audio-stream
# Repo: https://api.github.com/repos/deeeed/expo-audio-stream; Created At: 2024-04-20T06:22:22Z
# Requesting: https://api.github.com/repos/MaiM-with-u/MaiBot
# Repo: https://api.github.com/repos/MaiM-with-u/MaiBot; Created At: 2025-02-25T16:05:07Z
# Requesting: https://api.github.com/repos/SoftFever/OrcaSlicer
# Repo: https://api.github.com/repos/SoftFever/OrcaSlicer; Created At: 2022-07-16T11:01:21Z
# Requesting: https://api.github.com/repos/teddynote-lab/langconnect-client
# Repo: https://api.github.com/repos/teddynote-lab/langconnect-client; Created At: 2025-07-03T18:16:14Z
# Requesting: https://api.github.com/repos/luohy15/y-router
# Repo: https://api.github.com/repos/luohy15/y-router; Created At: 2025-07-12T15:17:31Z
# Requesting: https://api.github.com/repos/amantus-ai/vibetunnel
# Repo: https://api.github.com/repos/amantus-ai/vibetunnel; Created At: 2025-06-15T17:56:11Z
# Requesting: https://api.github.com/repos/friendsofhyperf/components
# Repo: https://api.github.com/repos/friendsofhyperf/components; Created At: 2022-05-20T06:40:25Z
# Requesting: https://api.github.com/repos/rishikanthc/Scriberr
# Repo: https://api.github.com/repos/rishikanthc/Scriberr; Created At: 2024-10-04T19:11:50Z
# Requesting: https://api.github.com/repos/operator-framework/operator-sdk
# Repo: https://api.github.com/repos/operator-framework/operator-sdk; Created At: 2018-02-07T17:53:51Z
# Requesting: https://api.github.com/repos/yuuki/tcpulse
# Repo: https://api.github.com/repos/yuuki/tcpulse; Created At: 2021-01-11T15:13:00Z
# Requesting: https://api.github.com/repos/Significant-Gravitas/AutoGPT
# Repo: https://api.github.com/repos/Significant-Gravitas/AutoGPT; Created At: 2023-03-16T09:21:07Z
# Requesting: https://api.github.com/repos/mitsuhiko/insta
# Repo: https://api.github.com/repos/mitsuhiko/insta; Created At: 2019-01-13T22:25:41Z
# Requesting: https://api.github.com/repos/anthropics/claude-code-action
# Repo: https://api.github.com/repos/anthropics/claude-code-action; Created At: 2025-05-19T15:26:50Z
# Requesting: https://api.github.com/repos/MeteorDevelopment/meteor-client
# Repo: https://api.github.com/repos/MeteorDevelopment/meteor-client; Created At: 2020-11-03T15:33:49Z
# Requesting: https://api.github.com/repos/kaichen/kimicc
# Repo: https://api.github.com/repos/kaichen/kimicc; Created At: 2025-07-13T14:36:16Z
# Requesting: https://api.github.com/repos/promptfoo/promptfoo
# Repo: https://api.github.com/repos/promptfoo/promptfoo; Created At: 2023-04-28T15:48:49Z
# Requesting: https://api.github.com/repos/ujisati/claude-code-provider-proxy
# Repo: https://api.github.com/repos/ujisati/claude-code-provider-proxy; Created At: 2025-03-27T06:44:21Z
# Requesting: https://api.github.com/repos/spacelift-io/spacectl
# Repo: https://api.github.com/repos/spacelift-io/spacectl; Created At: 2021-04-04T21:11:03Z
# Requesting: https://api.github.com/repos/umputun/spot
# Repo: https://api.github.com/repos/umputun/spot; Created At: 2023-04-21T01:18:48Z
# Requesting: https://api.github.com/repos/grafana/loki
# Repo: https://api.github.com/repos/grafana/loki; Created At: 2018-04-16T09:22:48Z
# Requesting: https://api.github.com/repos/maybe-finance/maybe
# Repo: https://api.github.com/repos/maybe-finance/maybe; Created At: 2024-01-01T22:23:46Z
# Requesting: https://api.github.com/repos/JessicaTegner/pypandoc
# Repo: https://api.github.com/repos/JessicaTegner/pypandoc; Created At: 2011-11-16T09:21:06Z
# Requesting: https://api.github.com/repos/coder/coder
# Repo: https://api.github.com/repos/coder/coder; Created At: 2021-12-22T06:08:52Z
# Requesting: https://api.github.com/repos/PrefectHQ/prefect
# Repo: https://api.github.com/repos/PrefectHQ/prefect; Created At: 2018-06-29T21:59:26Z
# Requesting: https://api.github.com/repos/SciML/DiffEqGPU.jl
# Repo: https://api.github.com/repos/SciML/DiffEqGPU.jl; Created At: 2019-06-24T19:22:02Z
# Requesting: https://api.github.com/repos/elizaOS/eliza
# Repo: https://api.github.com/repos/elizaOS/eliza; Created At: 2024-07-09T07:55:40Z
# Requesting: https://api.github.com/repos/czlonkowski/n8n-mcp
# Repo: https://api.github.com/repos/czlonkowski/n8n-mcp; Created At: 2025-06-07T12:15:57Z
# Requesting: https://api.github.com/repos/PRQL/prql
# Repo: https://api.github.com/repos/PRQL/prql; Created At: 2022-01-18T00:37:55Z
# Requesting: https://api.github.com/repos/kubernetes-sigs/cloud-provider-azure
# Repo: https://api.github.com/repos/kubernetes-sigs/cloud-provider-azure; Created At: 2018-03-21T06:25:16Z
# Requesting: https://api.github.com/repos/yoshiko-pg/difit
# Repo: https://api.github.com/repos/yoshiko-pg/difit; Created At: 2025-06-29T13:09:26Z
# Requesting: https://api.github.com/repos/geneontology/go-ontology
# Repo: https://api.github.com/repos/geneontology/go-ontology; Created At: 2015-06-19T23:29:57Z
# Requesting: https://api.github.com/repos/jdx/mise
# Repo: https://api.github.com/repos/jdx/mise; Created At: 2023-01-09T14:44:21Z
# Requesting: https://api.github.com/repos/Wan-Video/Wan2.1
# Repo: https://api.github.com/repos/Wan-Video/Wan2.1; Created At: 2025-02-25T11:49:33Z
# Requesting: https://api.github.com/repos/graphistry/pygraphistry
# Repo: https://api.github.com/repos/graphistry/pygraphistry; Created At: 2015-06-02T20:28:42Z
# Requesting: https://api.github.com/repos/sugyan/claude-code-webui
# Repo: https://api.github.com/repos/sugyan/claude-code-webui; Created At: 2025-06-10T03:06:25Z
# Requesting: https://api.github.com/repos/superfly/flyctl
# Repo: https://api.github.com/repos/superfly/flyctl; Created At: 2019-07-26T18:03:45Z
# Requesting: https://api.github.com/repos/buger/probe
# Repo: https://api.github.com/repos/buger/probe; Created At: 2025-03-05T16:09:15Z
# Requesting: https://api.github.com/repos/rcourtman/Pulse
# Repo: https://api.github.com/repos/rcourtman/Pulse; Created At: 2025-02-14T15:36:13Z
# Requesting: https://api.github.com/repos/567-labs/instructor
# Repo: https://api.github.com/repos/567-labs/instructor; Created At: 2023-06-14T10:42:23Z
# Requesting: https://api.github.com/repos/apache/pulsar
# Repo: https://api.github.com/repos/apache/pulsar; Created At: 2016-06-28T07:00:03Z
# Requesting: https://api.github.com/repos/fishaudio/fish-speech
# Repo: https://api.github.com/repos/fishaudio/fish-speech; Created At: 2023-10-10T03:16:51Z
# Requesting: https://api.github.com/repos/openemr/openemr-devops
# Repo: https://api.github.com/repos/openemr/openemr-devops; Created At: 2017-09-02T02:40:34Z
# Requesting: https://api.github.com/repos/OpenAdaptAI/OpenAdapt
# Repo: https://api.github.com/repos/OpenAdaptAI/OpenAdapt; Created At: 2023-04-12T16:20:23Z
# Requesting: https://api.github.com/repos/google-gemini/gemini-cli
# Repo: https://api.github.com/repos/google-gemini/gemini-cli; Created At: 2025-04-17T17:04:31Z
# Requesting: https://api.github.com/repos/gitpod-io/gitpod
# Repo: https://api.github.com/repos/gitpod-io/gitpod; Created At: 2018-04-24T15:56:54Z
# Requesting: https://api.github.com/repos/hypothesis/client
# Repo: https://api.github.com/repos/hypothesis/client; Created At: 2016-06-29T15:02:29Z
# Requesting: https://api.github.com/repos/ruvnet/claude-flow
# Repo: https://api.github.com/repos/ruvnet/claude-flow; Created At: 2025-06-02T21:24:20Z
# Requesting: https://api.github.com/repos/artsy/eigen
# Repo: https://api.github.com/repos/artsy/eigen; Created At: 2015-01-22T21:52:39Z
# Requesting: https://api.github.com/repos/shabegom/buttons
# Repo: https://api.github.com/repos/shabegom/buttons; Created At: 2021-03-27T13:05:01Z
# Requesting: https://api.github.com/repos/openai/openai-agents-js
# Repo: https://api.github.com/repos/openai/openai-agents-js; Created At: 2025-05-31T00:08:49Z
# Requesting: https://api.github.com/repos/meilisearch/meilisearch-mcp
# Repo: https://api.github.com/repos/meilisearch/meilisearch-mcp; Created At: 2024-12-23T14:53:05Z
# Requesting: https://api.github.com/repos/Wei-Shaw/claude-relay-service
# Repo: https://api.github.com/repos/Wei-Shaw/claude-relay-service; Created At: 2025-07-14T10:11:32Z
# Requesting: https://api.github.com/repos/J-Tech-Japan/Sekiban
# Repo: https://api.github.com/repos/J-Tech-Japan/Sekiban; Created At: 2023-05-25T05:14:51Z
# Requesting: https://api.github.com/repos/MCPJam/inspector
# Repo: https://api.github.com/repos/MCPJam/inspector; Created At: 2025-05-23T15:56:00Z
# Requesting: https://api.github.com/repos/jefago/tiny-markdown-editor
# Repo: https://api.github.com/repos/jefago/tiny-markdown-editor; Created At: 2020-02-27T07:37:04Z
# Requesting: https://api.github.com/repos/hmislk/hmis
# Repo: https://api.github.com/repos/hmislk/hmis; Created At: 2014-07-12T10:10:38Z
# Requesting: https://api.github.com/repos/bmadcode/BMAD-METHOD
# Repo: https://api.github.com/repos/bmadcode/BMAD-METHOD; Created At: 2025-04-13T14:54:25Z
# Requesting: https://api.github.com/repos/ithacaxyz/account
# Repo: https://api.github.com/repos/ithacaxyz/account; Created At: 2024-11-04T22:28:07Z
# Requesting: https://api.github.com/repos/mattermost/mattermost
# Repo: https://api.github.com/repos/mattermost/mattermost; Created At: 2015-06-15T06:50:02Z
# Requesting: https://api.github.com/repos/steipete/Peekaboo
# Repo: https://api.github.com/repos/steipete/Peekaboo; Created At: 2025-05-22T16:09:06Z
# Requesting: https://api.github.com/repos/dyoshikawa/rulesync
# Repo: https://api.github.com/repos/dyoshikawa/rulesync; Created At: 2025-06-18T13:27:05Z
# Requesting: https://api.github.com/repos/pdfme/pdfme
# Repo: https://api.github.com/repos/pdfme/pdfme; Created At: 2021-08-22T08:45:56Z
# Requesting: https://api.github.com/repos/karakeep-app/karakeep
# Repo: https://api.github.com/repos/karakeep-app/karakeep; Created At: 2024-02-06T12:28:31Z
# Requesting: https://api.github.com/repos/classmethod/tsumiki
# Repo: https://api.github.com/repos/classmethod/tsumiki; Created At: 2025-07-24T09:56:15Z
# Requesting: https://api.github.com/repos/steveklabnik/rue
# Repo: https://api.github.com/repos/steveklabnik/rue; Created At: 2025-06-05T03:47:59Z
# Requesting: https://api.github.com/repos/willccbb/verifiers
# Repo: https://api.github.com/repos/willccbb/verifiers; Created At: 2025-01-22T12:58:34Z
# Requesting: https://api.github.com/repos/Edgenesis/shifu
# Repo: https://api.github.com/repos/Edgenesis/shifu; Created At: 2021-08-09T08:15:25Z
# Requesting: https://api.github.com/repos/livestorejs/livestore
# Repo: https://api.github.com/repos/livestorejs/livestore; Created At: 2023-09-21T14:34:08Z
# Requesting: https://api.github.com/repos/liam-hq/liam
# Repo: https://api.github.com/repos/liam-hq/liam; Created At: 2024-08-07T07:11:45Z
# Requesting: https://api.github.com/repos/milvus-io/pymilvus
# Repo: https://api.github.com/repos/milvus-io/pymilvus; Created At: 2019-06-13T11:38:34Z
# Requesting: https://api.github.com/repos/thefrontside/effection
# Repo: https://api.github.com/repos/thefrontside/effection; Created At: 2018-11-02T19:56:47Z
# Requesting: https://api.github.com/repos/modelcontextprotocol/modelcontextprotocol
# Repo: https://api.github.com/repos/modelcontextprotocol/modelcontextprotocol; Created At: 2024-09-24T20:26:52Z
# Requesting: https://api.github.com/repos/zed-industries/zed
# Repo: https://api.github.com/repos/zed-industries/zed; Created At: 2021-02-20T03:01:06Z
# Requesting: https://api.github.com/repos/OpenAgentsInc/openagents
# Repo: https://api.github.com/repos/OpenAgentsInc/openagents; Created At: 2023-11-07T16:16:46Z
# Requesting: https://api.github.com/repos/wso2/product-is
# Repo: https://api.github.com/repos/wso2/product-is; Created At: 2014-04-21T08:55:36Z
# Requesting: https://api.github.com/repos/GMPrakhar/MAUI-Designer
# Repo: https://api.github.com/repos/GMPrakhar/MAUI-Designer; Created At: 2024-07-25T08:27:48Z
# Requesting: https://api.github.com/repos/zeroc-ice/ice-demos
# Repo: https://api.github.com/repos/zeroc-ice/ice-demos; Created At: 2015-02-24T16:09:41Z
# Requesting: https://api.github.com/repos/tuanpb99/cf-worker-telegram
# Repo: https://api.github.com/repos/tuanpb99/cf-worker-telegram; Created At: 2025-05-26T16:06:11Z
# Requesting: https://api.github.com/repos/OpenListTeam/OpenList
# Repo: https://api.github.com/repos/OpenListTeam/OpenList; Created At: 2025-06-11T23:35:02Z
# Requesting: https://api.github.com/repos/microsoft/vs-threading
# Repo: https://api.github.com/repos/microsoft/vs-threading; Created At: 2016-10-05T14:27:26Z
# Requesting: https://api.github.com/repos/github/github-mcp-server
# Repo: https://api.github.com/repos/github/github-mcp-server; Created At: 2025-03-04T16:42:04Z
# Requesting: https://api.github.com/repos/demergent-labs/azle
# Repo: https://api.github.com/repos/demergent-labs/azle; Created At: 2022-02-16T18:21:23Z
# Requesting: https://api.github.com/repos/docker/hello-genai
# Repo: https://api.github.com/repos/docker/hello-genai; Created At: 2025-03-28T09:49:19Z
# Requesting: https://api.github.com/repos/spack/spack
# Repo: https://api.github.com/repos/spack/spack; Created At: 2014-01-08T09:22:12Z
# Requesting: https://api.github.com/repos/coturn/coturn
# Repo: https://api.github.com/repos/coturn/coturn; Created At: 2015-07-17T08:15:16Z
# Requesting: https://api.github.com/repos/haydenbleasel/kibo
# Repo: https://api.github.com/repos/haydenbleasel/kibo; Created At: 2024-08-25T03:39:07Z
# Requesting: https://api.github.com/repos/Azure-Samples/rag-postgres-openai-python
# Repo: https://api.github.com/repos/Azure-Samples/rag-postgres-openai-python; Created At: 2024-05-14T18:09:19Z
# Requesting: https://api.github.com/repos/jeffkl/ManagedDism
# Repo: https://api.github.com/repos/jeffkl/ManagedDism; Created At: 2016-06-14T15:27:16Z
# Requesting: https://api.github.com/repos/dotnet/runtime
# Repo: https://api.github.com/repos/dotnet/runtime; Created At: 2019-09-24T23:36:39Z
# Requesting: https://api.github.com/repos/home-assistant/frontend
# Repo: https://api.github.com/repos/home-assistant/frontend; Created At: 2015-07-12T23:58:06Z
# Requesting: https://api.github.com/repos/thorsten/phpMyFAQ
# Repo: https://api.github.com/repos/thorsten/phpMyFAQ; Created At: 2009-08-04T19:26:15Z
# Requesting: https://api.github.com/repos/open-lambda/open-lambda
# Repo: https://api.github.com/repos/open-lambda/open-lambda; Created At: 2016-06-17T18:01:08Z
# Requesting: https://api.github.com/repos/streamich/memfs
# Repo: https://api.github.com/repos/streamich/memfs; Created At: 2015-06-15T20:50:40Z
# Requesting: https://api.github.com/repos/pwa-builder/PWABuilder
# Repo: https://api.github.com/repos/pwa-builder/PWABuilder; Created At: 2015-03-30T19:05:58Z
# Requesting: https://api.github.com/repos/stellar/rs-soroban-sdk
# Repo: https://api.github.com/repos/stellar/rs-soroban-sdk; Created At: 2022-04-08T16:47:37Z
# Requesting: https://api.github.com/repos/FerretDB/FerretDB
# Repo: https://api.github.com/repos/FerretDB/FerretDB; Created At: 2021-10-30T08:06:36Z
# Requesting: https://api.github.com/repos/source-academy/frontend
# Repo: https://api.github.com/repos/source-academy/frontend; Created At: 2018-05-12T09:50:48Z
# Requesting: https://api.github.com/repos/sysadminsmedia/homebox
# Repo: https://api.github.com/repos/sysadminsmedia/homebox; Created At: 2024-06-17T18:07:09Z
# Requesting: https://api.github.com/repos/trueai-org/module-shop
# Repo: https://api.github.com/repos/trueai-org/module-shop; Created At: 2019-04-26T09:19:44Z
# Requesting: https://api.github.com/repos/wieslawsoltes/Dock
# Repo: https://api.github.com/repos/wieslawsoltes/Dock; Created At: 2018-05-20T20:08:39Z
# Requesting: https://api.github.com/repos/microsoft/ebpf-for-windows
# Repo: https://api.github.com/repos/microsoft/ebpf-for-windows; Created At: 2021-04-08T00:32:50Z
# Requesting: https://api.github.com/repos/openai/openai-dotnet
# Repo: https://api.github.com/repos/openai/openai-dotnet; Created At: 2024-04-25T23:27:40Z
# Requesting: https://api.github.com/repos/dotnet/machinelearning
# Repo: https://api.github.com/repos/dotnet/machinelearning; Created At: 2018-05-03T16:20:42Z
# Requesting: https://api.github.com/repos/dotnet/sdk
# Repo: https://api.github.com/repos/dotnet/sdk; Created At: 2016-07-22T21:26:02Z
# Requesting: https://api.github.com/repos/valkey-io/valkey-glide
# Repo: https://api.github.com/repos/valkey-io/valkey-glide; Created At: 2022-07-06T13:08:07Z
# Requesting: https://api.github.com/repos/Azure/azure-functions-kafka-extension
# Repo: https://api.github.com/repos/Azure/azure-functions-kafka-extension; Created At: 2019-03-07T22:03:17Z
# Requesting: https://api.github.com/repos/Azure/autorest.typescript
# Repo: https://api.github.com/repos/Azure/autorest.typescript; Created At: 2017-08-24T06:29:08Z
# Requesting: https://api.github.com/repos/FirelyTeam/firely-net-sdk
# Repo: https://api.github.com/repos/FirelyTeam/firely-net-sdk; Created At: 2013-10-27T19:19:55Z
# Requesting: https://api.github.com/repos/microsoft/onnxruntime-genai
# Repo: https://api.github.com/repos/microsoft/onnxruntime-genai; Created At: 2023-11-13T20:37:15Z
# Requesting: https://api.github.com/repos/xlite-dev/lite.ai.toolkit
# Repo: https://api.github.com/repos/xlite-dev/lite.ai.toolkit; Created At: 2021-03-22T14:31:56Z
# Requesting: https://api.github.com/repos/v0l/snort
# Repo: https://api.github.com/repos/v0l/snort; Created At: 2022-12-18T14:50:49Z
# Requesting: https://api.github.com/repos/webgptorg/promptbook
# Repo: https://api.github.com/repos/webgptorg/promptbook; Created At: 2023-09-27T15:02:55Z
# Requesting: https://api.github.com/repos/nbonamy/witsy
# Repo: https://api.github.com/repos/nbonamy/witsy; Created At: 2024-04-25T03:55:22Z
# Requesting: https://api.github.com/repos/kubernetes-sigs/headlamp
# Repo: https://api.github.com/repos/kubernetes-sigs/headlamp; Created At: 2019-11-08T21:00:03Z
# Requesting: https://api.github.com/repos/microsoft/playwright-dotnet
# Repo: https://api.github.com/repos/microsoft/playwright-dotnet; Created At: 2020-01-22T12:52:16Z
# Requesting: https://api.github.com/repos/microsoft/promptpex
# Repo: https://api.github.com/repos/microsoft/promptpex; Created At: 2024-07-09T16:48:54Z
# Requesting: https://api.github.com/repos/MikePopoloski/slang
# Repo: https://api.github.com/repos/MikePopoloski/slang; Created At: 2017-02-03T22:20:21Z
# Requesting: https://api.github.com/repos/gpertea/gffcompare
# Repo: https://api.github.com/repos/gpertea/gffcompare; Created At: 2015-12-17T21:50:12Z
# Requesting: https://api.github.com/repos/unsend-dev/unsend
# Repo: https://api.github.com/repos/unsend-dev/unsend; Created At: 2024-03-14T22:16:24Z
# Requesting: https://api.github.com/repos/YunaiV/ruoyi-vue-pro
# Repo: https://api.github.com/repos/YunaiV/ruoyi-vue-pro; Created At: 2021-01-24T03:18:25Z
# Requesting: https://api.github.com/repos/serilog-contrib/serilog-enrichers-clientinfo
# Repo: https://api.github.com/repos/serilog-contrib/serilog-enrichers-clientinfo; Created At: 2019-12-05T19:58:44Z
# Requesting: https://api.github.com/repos/bryanedds/Nu
# Repo: https://api.github.com/repos/bryanedds/Nu; Created At: 2013-08-08T02:30:03Z
# Requesting: https://api.github.com/repos/djeada/Bash-Scripts
# Repo: https://api.github.com/repos/djeada/Bash-Scripts; Created At: 2019-03-19T18:56:56Z
# Requesting: https://api.github.com/repos/modelcontextprotocol/registry
# Repo: https://api.github.com/repos/modelcontextprotocol/registry; Created At: 2025-02-05T17:58:01Z
# Requesting: https://api.github.com/repos/alefragnani/vscode-bookmarks
# Repo: https://api.github.com/repos/alefragnani/vscode-bookmarks; Created At: 2015-11-14T12:31:40Z
# Requesting: https://api.github.com/repos/stevehansen/csv
# Repo: https://api.github.com/repos/stevehansen/csv; Created At: 2015-09-19T20:47:29Z
# Requesting: https://api.github.com/repos/Cosmian/kms
# Repo: https://api.github.com/repos/Cosmian/kms; Created At: 2023-05-10T18:48:50Z
# Requesting: https://api.github.com/repos/Azure/bicep
# Repo: https://api.github.com/repos/Azure/bicep; Created At: 2020-05-13T02:18:30Z
# Requesting: https://api.github.com/repos/messense/jieba-rs
# Repo: https://api.github.com/repos/messense/jieba-rs; Created At: 2018-05-06T09:41:22Z
# Requesting: https://api.github.com/repos/Tencent/tdesign-vue-next-starter
# Repo: https://api.github.com/repos/Tencent/tdesign-vue-next-starter; Created At: 2021-12-14T15:05:57Z
# Requesting: https://api.github.com/repos/modelcontextprotocol/csharp-sdk
# Repo: https://api.github.com/repos/modelcontextprotocol/csharp-sdk; Created At: 2025-03-10T18:17:41Z
# Requesting: https://api.github.com/repos/arc53/DocsGPT
# Repo: https://api.github.com/repos/arc53/DocsGPT; Created At: 2023-02-02T11:03:23Z
# Requesting: https://api.github.com/repos/git/git-scm.com
# Repo: https://api.github.com/repos/git/git-scm.com; Created At: 2012-03-08T17:16:41Z
# Requesting: https://api.github.com/repos/514-labs/moose
# Repo: https://api.github.com/repos/514-labs/moose; Created At: 2023-07-20T00:23:21Z
# Requesting: https://api.github.com/repos/Animetailapp/Animetail
# Repo: https://api.github.com/repos/Animetailapp/Animetail; Created At: 2023-11-26T14:25:53Z
# Requesting: https://api.github.com/repos/Ljzd-PRO/KToolBox
# Repo: https://api.github.com/repos/Ljzd-PRO/KToolBox; Created At: 2023-11-06T15:24:12Z
# Requesting: https://api.github.com/repos/pamelafox/python-openai-demos
# Repo: https://api.github.com/repos/pamelafox/python-openai-demos; Created At: 2024-03-23T13:44:12Z
# Requesting: https://api.github.com/repos/Azure/azqr
# Repo: https://api.github.com/repos/Azure/azqr; Created At: 2022-10-17T09:47:59Z
# Requesting: https://api.github.com/repos/andrewlock/NetEscapades.EnumGenerators
# Repo: https://api.github.com/repos/andrewlock/NetEscapades.EnumGenerators; Created At: 2021-11-17T22:33:21Z
# Requesting: https://api.github.com/repos/microsoft/windows-drivers-rs
# Repo: https://api.github.com/repos/microsoft/windows-drivers-rs; Created At: 2023-09-16T21:45:21Z
# Requesting: https://api.github.com/repos/longbridge/gpui-component
# Repo: https://api.github.com/repos/longbridge/gpui-component; Created At: 2024-06-13T13:45:39Z
# Requesting: https://api.github.com/repos/typstyle-rs/typstyle
# Repo: https://api.github.com/repos/typstyle-rs/typstyle; Created At: 2024-03-09T04:46:08Z
# Requesting: https://api.github.com/repos/binarywang/WxJava
# Repo: https://api.github.com/repos/binarywang/WxJava; Created At: 2016-01-06T08:24:05Z
# Requesting: https://api.github.com/repos/EduMIPS64/edumips64
# Repo: https://api.github.com/repos/EduMIPS64/edumips64; Created At: 2011-09-05T08:43:04Z
# Requesting: https://api.github.com/repos/Epix-Incorporated/Adonis
# Repo: https://api.github.com/repos/Epix-Incorporated/Adonis; Created At: 2016-04-03T02:00:01Z
# Requesting: https://api.github.com/repos/camunda/camunda
# Repo: https://api.github.com/repos/camunda/camunda; Created At: 2016-03-20T03:38:04Z
# Requesting: https://api.github.com/repos/microsoft/react-native-windows-samples
# Repo: https://api.github.com/repos/microsoft/react-native-windows-samples; Created At: 2019-09-16T21:04:57Z
# Requesting: https://api.github.com/repos/OrchardCMS/OrchardCore
# Repo: https://api.github.com/repos/OrchardCMS/OrchardCore; Created At: 2014-11-19T22:29:26Z
# Requesting: https://api.github.com/repos/rohitg00/awesome-ai-apps
# Repo: https://api.github.com/repos/rohitg00/awesome-ai-apps; Created At: 2025-06-12T10:12:14Z
# Requesting: https://api.github.com/repos/Azure/autorest.csharp
# Repo: https://api.github.com/repos/Azure/autorest.csharp; Created At: 2017-08-14T22:52:14Z
# Requesting: https://api.github.com/repos/nearai/nearai
# Repo: https://api.github.com/repos/nearai/nearai; Created At: 2024-05-08T00:22:09Z
# Requesting: https://api.github.com/repos/radius-project/radius
# Repo: https://api.github.com/repos/radius-project/radius; Created At: 2021-02-20T00:25:52Z
# Requesting: https://api.github.com/repos/midudev/landing-infojobs
# Repo: https://api.github.com/repos/midudev/landing-infojobs; Created At: 2024-10-16T17:28:51Z
# Requesting: https://api.github.com/repos/Azure/intelligent-app-workshop
# Repo: https://api.github.com/repos/Azure/intelligent-app-workshop; Created At: 2023-04-16T22:24:17Z
# Requesting: https://api.github.com/repos/taiga-family/taiga-ui
# Repo: https://api.github.com/repos/taiga-family/taiga-ui; Created At: 2020-09-25T16:09:18Z
# Requesting: https://api.github.com/repos/openshift-pipelines/pipelines-as-code
# Repo: https://api.github.com/repos/openshift-pipelines/pipelines-as-code; Created At: 2021-04-06T13:26:01Z
# Requesting: https://api.github.com/repos/Cysharp/MagicOnion
# Repo: https://api.github.com/repos/Cysharp/MagicOnion; Created At: 2016-12-10T08:32:33Z
# Requesting: https://api.github.com/repos/baynezy/Html2Markdown
# Repo: https://api.github.com/repos/baynezy/Html2Markdown; Created At: 2013-07-03T06:06:50Z
# Requesting: https://api.github.com/repos/benbalter/jekyll-relative-links
# Repo: https://api.github.com/repos/benbalter/jekyll-relative-links; Created At: 2016-11-17T05:38:00Z
# Requesting: https://api.github.com/repos/microsoft/windows-rs
# Repo: https://api.github.com/repos/microsoft/windows-rs; Created At: 2019-09-12T17:03:25Z
# Requesting: https://api.github.com/repos/middleman/middleman-syntax
# Repo: https://api.github.com/repos/middleman/middleman-syntax; Created At: 2012-09-17T06:19:18Z
# Requesting: https://api.github.com/repos/pyushkevich/itksnap
# Repo: https://api.github.com/repos/pyushkevich/itksnap; Created At: 2014-04-23T06:46:21Z
# Requesting: https://api.github.com/repos/14790897/handwriting-web
# Repo: https://api.github.com/repos/14790897/handwriting-web; Created At: 2023-06-15T12:22:29Z
# Requesting: https://api.github.com/repos/Diniboy1123/usque
# Repo: https://api.github.com/repos/Diniboy1123/usque; Created At: 2025-02-20T13:26:28Z
# Requesting: https://api.github.com/repos/middleman/middleman-blog
# Repo: https://api.github.com/repos/middleman/middleman-blog; Created At: 2011-08-20T00:45:44Z
# Requesting: https://api.github.com/repos/abh/ntppool
# Repo: https://api.github.com/repos/abh/ntppool; Created At: 2008-07-12T10:28:00Z
# Requesting: https://api.github.com/repos/jihadkhawaja/Egroo
# Repo: https://api.github.com/repos/jihadkhawaja/Egroo; Created At: 2021-06-11T12:26:45Z
# Requesting: https://api.github.com/repos/commons-app/apps-android-commons
# Repo: https://api.github.com/repos/commons-app/apps-android-commons; Created At: 2015-09-07T05:23:27Z
# Requesting: https://api.github.com/repos/Azure/azure-sdk-for-rust
# Repo: https://api.github.com/repos/Azure/azure-sdk-for-rust; Created At: 2020-09-15T18:05:06Z
# Requesting: https://api.github.com/repos/github/brasil
# Repo: https://api.github.com/repos/github/brasil; Created At: 2023-04-28T20:24:43Z
# Requesting: https://api.github.com/repos/ant-design/ant-design
# Repo: https://api.github.com/repos/ant-design/ant-design; Created At: 2015-04-24T15:37:24Z
# Requesting: https://api.github.com/repos/evstack/ev-node
# Repo: https://api.github.com/repos/evstack/ev-node; Created At: 2021-02-03T09:28:24Z
# Requesting: https://api.github.com/repos/easyops-cn/docusaurus-search-local
# Repo: https://api.github.com/repos/easyops-cn/docusaurus-search-local; Created At: 2020-10-18T07:32:46Z
# Requesting: https://api.github.com/repos/microsoft/azure-devops-mcp
# Repo: https://api.github.com/repos/microsoft/azure-devops-mcp; Created At: 2025-05-15T13:12:42Z
# Requesting: https://api.github.com/repos/elonen/clapshot
# Repo: https://api.github.com/repos/elonen/clapshot; Created At: 2022-09-18T19:53:43Z
# Requesting: https://api.github.com/repos/DonDebonair/slack-machine
# Repo: https://api.github.com/repos/DonDebonair/slack-machine; Created At: 2017-09-01T10:26:33Z
# Requesting: https://api.github.com/repos/bennycode/trading-signals
# Repo: https://api.github.com/repos/bennycode/trading-signals; Created At: 2020-05-28T10:44:05Z
# Requesting: https://api.github.com/repos/bettse/seader
# Repo: https://api.github.com/repos/bettse/seader; Created At: 2023-06-18T00:06:09Z
# Requesting: https://api.github.com/repos/vespa-engine/pyvespa
# Repo: https://api.github.com/repos/vespa-engine/pyvespa; Created At: 2020-06-10T10:48:27Z
# Requesting: https://api.github.com/repos/kubernetes/enhancements
# Repo: https://api.github.com/repos/kubernetes/enhancements; Created At: 2016-05-02T18:51:30Z
# Requesting: https://api.github.com/repos/geoserver/geoserver
# Repo: https://api.github.com/repos/geoserver/geoserver; Created At: 2011-11-10T19:56:06Z
# Requesting: https://api.github.com/repos/manekinekko/angular-web-bluetooth
# Repo: https://api.github.com/repos/manekinekko/angular-web-bluetooth; Created At: 2016-12-27T20:40:08Z
# Requesting: https://api.github.com/repos/microsoft/Nova
# Repo: https://api.github.com/repos/microsoft/Nova; Created At: 2021-07-22T17:39:31Z
# Requesting: https://api.github.com/repos/dotnet/Nerdbank.GitVersioning
# Repo: https://api.github.com/repos/dotnet/Nerdbank.GitVersioning; Created At: 2015-05-17T04:39:48Z
# Requesting: https://api.github.com/repos/safedep/vet
# Repo: https://api.github.com/repos/safedep/vet; Created At: 2022-12-30T03:39:03Z
# Requesting: https://api.github.com/repos/elastic/integrations
# Repo: https://api.github.com/repos/elastic/integrations; Created At: 2019-08-13T11:11:07Z
# Requesting: https://api.github.com/repos/ESP32Async/ESPAsyncWebServer
# Repo: https://api.github.com/repos/ESP32Async/ESPAsyncWebServer; Created At: 2025-01-20T16:22:49Z
# Requesting: https://api.github.com/repos/nyaruka/courier
# Repo: https://api.github.com/repos/nyaruka/courier; Created At: 2017-05-10T16:38:44Z
# Requesting: https://api.github.com/repos/Azure/azure-sdk-for-python
# Repo: https://api.github.com/repos/Azure/azure-sdk-for-python; Created At: 2012-04-24T16:46:12Z
# Requesting: https://api.github.com/repos/dalathegreat/Battery-Emulator
# Repo: https://api.github.com/repos/dalathegreat/Battery-Emulator; Created At: 2023-02-19T19:21:29Z
# Requesting: https://api.github.com/repos/dotnet/wcf
# Repo: https://api.github.com/repos/dotnet/wcf; Created At: 2015-05-13T17:17:03Z
# Requesting: https://api.github.com/repos/bugsink/bugsink
# Repo: https://api.github.com/repos/bugsink/bugsink; Created At: 2024-08-21T06:19:56Z
# Requesting: https://api.github.com/repos/sgb-io/fta
# Repo: https://api.github.com/repos/sgb-io/fta; Created At: 2023-05-07T13:10:15Z
# Requesting: https://api.github.com/repos/istio/istio
# Repo: https://api.github.com/repos/istio/istio; Created At: 2016-11-18T23:57:21Z
# Requesting: https://api.github.com/repos/AIDotNet/Thor
# Repo: https://api.github.com/repos/AIDotNet/Thor; Created At: 2024-03-16T07:37:45Z
# Requesting: https://api.github.com/repos/stefankoegl/python-json-pointer
# Repo: https://api.github.com/repos/stefankoegl/python-json-pointer; Created At: 2011-07-31T19:53:51Z
# Requesting: https://api.github.com/repos/python-cachier/cachier
# Repo: https://api.github.com/repos/python-cachier/cachier; Created At: 2016-08-24T13:34:12Z
# Requesting: https://api.github.com/repos/aki77/activestorage-validator
# Repo: https://api.github.com/repos/aki77/activestorage-validator; Created At: 2018-09-18T01:26:35Z
# Requesting: https://api.github.com/repos/DeepLabCut/DeepLabCut
# Repo: https://api.github.com/repos/DeepLabCut/DeepLabCut; Created At: 2018-03-26T22:29:12Z
# Requesting: https://api.github.com/repos/EmmyLuaLs/emmylua-analyzer-rust
# Repo: https://api.github.com/repos/EmmyLuaLs/emmylua-analyzer-rust; Created At: 2024-10-15T07:45:06Z
# Requesting: https://api.github.com/repos/dotnet/java-interop
# Repo: https://api.github.com/repos/dotnet/java-interop; Created At: 2014-02-11T16:58:59Z
# Requesting: https://api.github.com/repos/vapourismo/knx-go
# Repo: https://api.github.com/repos/vapourismo/knx-go; Created At: 2017-04-28T14:25:58Z
# Requesting: https://api.github.com/repos/amber-lang/amber
# Repo: https://api.github.com/repos/amber-lang/amber; Created At: 2022-07-20T19:15:54Z
# Requesting: https://api.github.com/repos/lutzroeder/netron
# Repo: https://api.github.com/repos/lutzroeder/netron; Created At: 2010-12-26T12:53:43Z
# Requesting: https://api.github.com/repos/ajthinking/data-story
# Repo: https://api.github.com/repos/ajthinking/data-story; Created At: 2020-12-18T18:23:19Z
# Requesting: https://api.github.com/repos/vitejs/vite
# Repo: https://api.github.com/repos/vitejs/vite; Created At: 2020-04-21T05:03:57Z
# ...
# Requesting: https://api.github.com/repos/tumf/mcp-text-editor
# Error during GitHub API request for https://api.github.com/repos/tumf/mcp-text-editor: 403 Client Error: Forbidden for url: https://api.github.com/repos/tumf/mcp-text-editor
# Requesting: https://api.github.com/repos/hyperweb-io/telescope
# Error during GitHub API request for https://api.github.com/repos/hyperweb-io/telescope: 403 Client Error: Forbidden for url: https://api.github.com/repos/hyperweb-io/telescope
# Requesting: https://api.github.com/repos/vlm-run/vlmrun-hub
# Error during GitHub API request for https://api.github.com/repos/vlm-run/vlmrun-hub: 403 Client Error: Forbidden for url: https://api.github.com/repos/vlm-run/vlmrun-hub
# Requesting: https://api.github.com/repos/GlareDB/glaredb
# Error during GitHub API request for https://api.github.com/repos/GlareDB/glaredb: 403 Client Error: Forbidden for url: https://api.github.com/repos/GlareDB/glaredb
# Requesting: https://api.github.com/repos/auchenberg/claude-code-mcp
# Error during GitHub API request for https://api.github.com/repos/auchenberg/claude-code-mcp: 403 Client Error: Forbidden for url: https://api.github.com/repos/auchenberg/claude-code-mcp
# Requesting: https://api.github.com/repos/disler/single-file-agents
# Error during GitHub API request for https://api.github.com/repos/disler/single-file-agents: 403 Client Error: Forbidden for url: https://api.github.com/repos/disler/single-file-agents
# Requesting: https://api.github.com/repos/hcengineering/platform
# Error during GitHub API request for https://api.github.com/repos/hcengineering/platform: 403 Client Error: Forbidden for url: https://api.github.com/repos/hcengineering/platform
# Requesting: https://api.github.com/repos/Mail-0/Zero
# Error during GitHub API request for https://api.github.com/repos/Mail-0/Zero: 403 Client Error: Forbidden for url: https://api.github.com/repos/Mail-0/Zero
# Requesting: https://api.github.com/repos/noneback/go-taskflow
# Error during GitHub API request for https://api.github.com/repos/noneback/go-taskflow: 403 Client Error: Forbidden for url: https://api.github.com/repos/noneback/go-taskflow
# Requesting: https://api.github.com/repos/deeptrust-ai/terifai-open
# Error during GitHub API request for https://api.github.com/repos/deeptrust-ai/terifai-open: 403 Client Error: Forbidden for url: https://api.github.com/repos/deeptrust-ai/terifai-open
# Requesting: https://api.github.com/repos/baserproject/basercms
# Error during GitHub API request for https://api.github.com/repos/baserproject/basercms: 403 Client Error: Forbidden for url: https://api.github.com/repos/baserproject/basercms
# Requesting: https://api.github.com/repos/LIT-Protocol/js-sdk
# Error during GitHub API request for https://api.github.com/repos/LIT-Protocol/js-sdk: 403 Client Error: Forbidden for url: https://api.github.com/repos/LIT-Protocol/js-sdk
# Requesting: https://api.github.com/repos/daimo-eth/daimo
# Error during GitHub API request for https://api.github.com/repos/daimo-eth/daimo: 403 Client Error: Forbidden for url: https://api.github.com/repos/daimo-eth/daimo
# Requesting: https://api.github.com/repos/NethermindEth/starknet.go
# Error during GitHub API request for https://api.github.com/repos/NethermindEth/starknet.go: 403 Client Error: Forbidden for url: https://api.github.com/repos/NethermindEth/starknet.go
# Requesting: https://api.github.com/repos/zaidmukaddam/scira
# Error during GitHub API request for https://api.github.com/repos/zaidmukaddam/scira: 403 Client Error: Forbidden for url: https://api.github.com/repos/zaidmukaddam/scira
# Requesting: https://api.github.com/repos/toeverything/AFFiNE
# Error during GitHub API request for https://api.github.com/repos/toeverything/AFFiNE: 403 Client Error: Forbidden for url: https://api.github.com/repos/toeverything/AFFiNE
# Requesting: https://api.github.com/repos/browserbase/stagehand
# Error during GitHub API request for https://api.github.com/repos/browserbase/stagehand: 403 Client Error: Forbidden for url: https://api.github.com/repos/browserbase/stagehand
# Requesting: https://api.github.com/repos/patched-codes/patchwork
# Error during GitHub API request for https://api.github.com/repos/patched-codes/patchwork: 403 Client Error: Forbidden for url: https://api.github.com/repos/patched-codes/patchwork
# Requesting: https://api.github.com/repos/buffdb/buffdb
# Error during GitHub API request for https://api.github.com/repos/buffdb/buffdb: 403 Client Error: Forbidden for url: https://api.github.com/repos/buffdb/buffdb
# Requesting: https://api.github.com/repos/antiwork/gumroad-v1
# Error during GitHub API request for https://api.github.com/repos/antiwork/gumroad-v1: 403 Client Error: Forbidden for url: https://api.github.com/repos/antiwork/gumroad-v1
# Requesting: https://api.github.com/repos/harrisonwang/docxy
# Error during GitHub API request for https://api.github.com/repos/harrisonwang/docxy: 403 Client Error: Forbidden for url: https://api.github.com/repos/harrisonwang/docxy
# Requesting: https://api.github.com/repos/modal-labs/modal-client
# Error during GitHub API request for https://api.github.com/repos/modal-labs/modal-client: 403 Client Error: Forbidden for url: https://api.github.com/repos/modal-labs/modal-client
# Requesting: https://api.github.com/repos/wealthsimple/llm-gateway
# Error during GitHub API request for https://api.github.com/repos/wealthsimple/llm-gateway: 403 Client Error: Forbidden for url: https://api.github.com/repos/wealthsimple/llm-gateway
# Requesting: https://api.github.com/repos/box/boxcli
# Error during GitHub API request for https://api.github.com/repos/box/boxcli: 403 Client Error: Forbidden for url: https://api.github.com/repos/box/boxcli
# Requesting: https://api.github.com/repos/neondatabase/neon
# Error during GitHub API request for https://api.github.com/repos/neondatabase/neon: 403 Client Error: Forbidden for url: https://api.github.com/repos/neondatabase/neon
# Requesting: https://api.github.com/repos/codemod-com/codemod
# Error during GitHub API request for https://api.github.com/repos/codemod-com/codemod: 403 Client Error: Forbidden for url: https://api.github.com/repos/codemod-com/codemod
# Requesting: https://api.github.com/repos/zeta-chain/node
# Error during GitHub API request for https://api.github.com/repos/zeta-chain/node: 403 Client Error: Forbidden for url: https://api.github.com/repos/zeta-chain/node
# Requesting: https://api.github.com/repos/azu/promises-book
# Error during GitHub API request for https://api.github.com/repos/azu/promises-book: 403 Client Error: Forbidden for url: https://api.github.com/repos/azu/promises-book
# Requesting: https://api.github.com/repos/jina-ai/deepsearch-ui
# Error during GitHub API request for https://api.github.com/repos/jina-ai/deepsearch-ui: 403 Client Error: Forbidden for url: https://api.github.com/repos/jina-ai/deepsearch-ui
# Requesting: https://api.github.com/repos/oekazuma/svelte-meta-tags
# Error during GitHub API request for https://api.github.com/repos/oekazuma/svelte-meta-tags: 403 Client Error: Forbidden for url: https://api.github.com/repos/oekazuma/svelte-meta-tags
# Requesting: https://api.github.com/repos/Mooncake-Labs/pg_mooncake
# Error during GitHub API request for https://api.github.com/repos/Mooncake-Labs/pg_mooncake: 403 Client Error: Forbidden for url: https://api.github.com/repos/Mooncake-Labs/pg_mooncake
# Requesting: https://api.github.com/repos/mendableai/firecrawl-mcp-server
# Error during GitHub API request for https://api.github.com/repos/mendableai/firecrawl-mcp-server: 403 Client Error: Forbidden for url: https://api.github.com/repos/mendableai/firecrawl-mcp-server
# Requesting: https://api.github.com/repos/bespokelabsai/curator
# Error during GitHub API request for https://api.github.com/repos/bespokelabsai/curator: 403 Client Error: Forbidden for url: https://api.github.com/repos/bespokelabsai/curator
# Requesting: https://api.github.com/repos/TempleDevelopment/TempleWare-Legacy
# Error during GitHub API request for https://api.github.com/repos/TempleDevelopment/TempleWare-Legacy: 403 Client Error: Forbidden for url: https://api.github.com/repos/TempleDevelopment/TempleWare-Legacy
# Requesting: https://api.github.com/repos/formancehq/ledger
# Error during GitHub API request for https://api.github.com/repos/formancehq/ledger: 403 Client Error: Forbidden for url: https://api.github.com/repos/formancehq/ledger
# Requesting: https://api.github.com/repos/legions-developer/invoicely
# Error during GitHub API request for https://api.github.com/repos/legions-developer/invoicely: 403 Client Error: Forbidden for url: https://api.github.com/repos/legions-developer/invoicely
# Requesting: https://api.github.com/repos/NangoHQ/nango
# Error during GitHub API request for https://api.github.com/repos/NangoHQ/nango: 403 Client Error: Forbidden for url: https://api.github.com/repos/NangoHQ/nango
# Requesting: https://api.github.com/repos/neondatabase/autoscaling
# Error during GitHub API request for https://api.github.com/repos/neondatabase/autoscaling: 403 Client Error: Forbidden for url: https://api.github.com/repos/neondatabase/autoscaling
# Requesting: https://api.github.com/repos/evergreen-ci/evergreen
# Error during GitHub API request for https://api.github.com/repos/evergreen-ci/evergreen: 403 Client Error: Forbidden for url: https://api.github.com/repos/evergreen-ci/evergreen
# Requesting: https://api.github.com/repos/hoophq/hoop
# Error during GitHub API request for https://api.github.com/repos/hoophq/hoop: 403 Client Error: Forbidden for url: https://api.github.com/repos/hoophq/hoop
# Requesting: https://api.github.com/repos/LottieFiles/dotlottie-web
# Error during GitHub API request for https://api.github.com/repos/LottieFiles/dotlottie-web: 403 Client Error: Forbidden for url: https://api.github.com/repos/LottieFiles/dotlottie-web
# Requesting: https://api.github.com/repos/appdotbuild/agent
# Error during GitHub API request for https://api.github.com/repos/appdotbuild/agent: 403 Client Error: Forbidden for url: https://api.github.com/repos/appdotbuild/agent
# Requesting: https://api.github.com/repos/AgentDock/AgentDock
# Error during GitHub API request for https://api.github.com/repos/AgentDock/AgentDock: 403 Client Error: Forbidden for url: https://api.github.com/repos/AgentDock/AgentDock
# Requesting: https://api.github.com/repos/BasedHardware/omi
# Error during GitHub API request for https://api.github.com/repos/BasedHardware/omi: 403 Client Error: Forbidden for url: https://api.github.com/repos/BasedHardware/omi
# Requesting: https://api.github.com/repos/antiwork/shortest
# Error during GitHub API request for https://api.github.com/repos/antiwork/shortest: 403 Client Error: Forbidden for url: https://api.github.com/repos/antiwork/shortest
# Requesting: https://api.github.com/repos/juicyllama/llana
# Error during GitHub API request for https://api.github.com/repos/juicyllama/llana: 403 Client Error: Forbidden for url: https://api.github.com/repos/juicyllama/llana
# Requesting: https://api.github.com/repos/enzonotario/vitepress-openapi
# Error during GitHub API request for https://api.github.com/repos/enzonotario/vitepress-openapi: 403 Client Error: Forbidden for url: https://api.github.com/repos/enzonotario/vitepress-openapi
# Requesting: https://api.github.com/repos/ReactiveCircus/android-emulator-runner
# Error during GitHub API request for https://api.github.com/repos/ReactiveCircus/android-emulator-runner: 403 Client Error: Forbidden for url: https://api.github.com/repos/ReactiveCircus/android-emulator-runner
# Requesting: https://api.github.com/repos/auros-one/tauri-sveltekit
# Error during GitHub API request for https://api.github.com/repos/auros-one/tauri-sveltekit: 403 Client Error: Forbidden for url: https://api.github.com/repos/auros-one/tauri-sveltekit
# Requesting: https://api.github.com/repos/cornerstonejs/cornerstone3D
# Error during GitHub API request for https://api.github.com/repos/cornerstonejs/cornerstone3D: 403 Client Error: Forbidden for url: https://api.github.com/repos/cornerstonejs/cornerstone3D
# Requesting: https://api.github.com/repos/triggerdotdev/trigger.dev
# Error during GitHub API request for https://api.github.com/repos/triggerdotdev/trigger.dev: 403 Client Error: Forbidden for url: https://api.github.com/repos/triggerdotdev/trigger.dev
# Requesting: https://api.github.com/repos/neondatabase-labs/mcp-server-neon
# Error during GitHub API request for https://api.github.com/repos/neondatabase-labs/mcp-server-neon: 403 Client Error: Forbidden for url: https://api.github.com/repos/neondatabase-labs/mcp-server-neon
# Requesting: https://api.github.com/repos/KomodoPlatform/komodo-defi-framework
# Error during GitHub API request for https://api.github.com/repos/KomodoPlatform/komodo-defi-framework: 403 Client Error: Forbidden for url: https://api.github.com/repos/KomodoPlatform/komodo-defi-framework
# Requesting: https://api.github.com/repos/openvm-org/openvm
# Error during GitHub API request for https://api.github.com/repos/openvm-org/openvm: 403 Client Error: Forbidden for url: https://api.github.com/repos/openvm-org/openvm
# Requesting: https://api.github.com/repos/team-mirai/policy
# Error during GitHub API request for https://api.github.com/repos/team-mirai/policy: 403 Client Error: Forbidden for url: https://api.github.com/repos/team-mirai/policy
# Requesting: https://api.github.com/repos/labring/laf
# Error during GitHub API request for https://api.github.com/repos/labring/laf: 403 Client Error: Forbidden for url: https://api.github.com/repos/labring/laf
# Requesting: https://api.github.com/repos/ag2ai/fastagency
# Error during GitHub API request for https://api.github.com/repos/ag2ai/fastagency: 403 Client Error: Forbidden for url: https://api.github.com/repos/ag2ai/fastagency
# Requesting: https://api.github.com/repos/wandb/wandb
# Error during GitHub API request for https://api.github.com/repos/wandb/wandb: 403 Client Error: Forbidden for url: https://api.github.com/repos/wandb/wandb
# Requesting: https://api.github.com/repos/brevdev/brev-cli
# Error during GitHub API request for https://api.github.com/repos/brevdev/brev-cli: 403 Client Error: Forbidden for url: https://api.github.com/repos/brevdev/brev-cli
# Requesting: https://api.github.com/repos/whitphx/stlite
# Error during GitHub API request for https://api.github.com/repos/whitphx/stlite: 403 Client Error: Forbidden for url: https://api.github.com/repos/whitphx/stlite
# Requesting: https://api.github.com/repos/fatedier/fft
# Error during GitHub API request for https://api.github.com/repos/fatedier/fft: 403 Client Error: Forbidden for url: https://api.github.com/repos/fatedier/fft
# Requesting: https://api.github.com/repos/saturday06/VRM-Addon-for-Blender
# Error during GitHub API request for https://api.github.com/repos/saturday06/VRM-Addon-for-Blender: 403 Client Error: Forbidden for url: https://api.github.com/repos/saturday06/VRM-Addon-for-Blender
# Requesting: https://api.github.com/repos/reservoirprotocol/marketplace-v2
# Error during GitHub API request for https://api.github.com/repos/reservoirprotocol/marketplace-v2: 403 Client Error: Forbidden for url: https://api.github.com/repos/reservoirprotocol/marketplace-v2
# Requesting: https://api.github.com/repos/wolfSSL/wolfssl
# Error during GitHub API request for https://api.github.com/repos/wolfSSL/wolfssl: 403 Client Error: Forbidden for url: https://api.github.com/repos/wolfSSL/wolfssl
# Requesting: https://api.github.com/repos/nexus-xyz/nexus-cli
# Error during GitHub API request for https://api.github.com/repos/nexus-xyz/nexus-cli: 403 Client Error: Forbidden for url: https://api.github.com/repos/nexus-xyz/nexus-cli
# Requesting: https://api.github.com/repos/domaframework/doma
# Error during GitHub API request for https://api.github.com/repos/domaframework/doma: 403 Client Error: Forbidden for url: https://api.github.com/repos/domaframework/doma
# Requesting: https://api.github.com/repos/Yamashou/gqlgenc
# Error during GitHub API request for https://api.github.com/repos/Yamashou/gqlgenc: 403 Client Error: Forbidden for url: https://api.github.com/repos/Yamashou/gqlgenc
# Number of Repositories: 1686

# %% [markdown]
# # **Third**, Gather the covariant variables
#
# They use two CSVs, treatment_metrics.csv and control_metrics.csv
#
#
# ## PR Variables
# 1. **additions:** The # of added LOC by a PR
# 2. **deletions:** The # of deleted LOC by a PR
# 3. **prSize:** The total nunber of added and deleted LOC by a PR (additions + deletions)
# 4. **purpose:** The purpose of a PR, i.e., bug, document, and feature. Simple keyword search in the title/body ('fix', 'bug', 'doc', …).
# 5. **changedFiles:** The # of files changed by a PR
# 6. **commitsTotalCount:** The # of commits involved in a PR
# 7. **Description length:** The length of a PR description
# 8. **prExperience:** The # of prior PRs that were submitted by the PR author (author’s prior PR count). Query the author’s PR history in the same repo and count PRs created before the current one.
# 9. **isMember:** Whether or not the author is a member or outside collaborator (True/False).
# 10. **commentsTotalCount:** The # of comments left on a PR
# 11. **authorComments:** The # of comments left by the PR author
# 12. **reviewersComments:** The # of comments left by the reviewers who participate in the disucssion
# 13. **reviewersTotalCount:** The # of developers who participate in the discussion.
# 14. **repoAge:** Time interval between the repository creation time and PR creation time in days.
# 15. **state**: State of the pull request (MERGED or CLOSED).
# 16. **bodyLength**: Length of the PR body (in characters).
# 17. **reviewTime**: Time taken to review the PR (in hours, floating point, no rounding).
#
#
# ## Project variables
#
# 18. **repoLanguage:** Programming language of the repository (e.g., Python, PHP, TypeScript, Vue). *[I'm assuming its the top language as there is only one]*
# 19. **forkCount:** The # of forks that a repository has
# 20. **stargazerCount:** The # of stargazers that a repository has.
#
# ## Treatment variables
#
# 21. **With Copilot for PRs:** Whether or not a PR is generated by Copilot for PRs (binary)
#
# ## Outcome variables
#
# 22. **Review time (reviewTime):** Time interval between the PR creation time and closed time in hours
# 23. **Is merged (state):** Whether or not a PR is merged (binary)
#
#
# ### Order in CSV (treatment_metrics.csv and control_metrics.csc)
# 1. **repoLanguage**
# 2. **forkCount**
# 3. **stargazerCount**
# 4. **repoAge**
# 5. **state**
# 6. **deletions**
# 7. **additions**
# 8. **changedFiles**
# 9. **commentsTotalCount**
# 10. **commitsTotalCount**
# 11. **prExperience**
# 12. **isMember**
# 13. **authorComments**
# 14. **reviewersComments**
# 15. **reviewersTotalCount**
# 16. **bodyLength**
# 17. **prSize**
# 18. **reviewTime**
# 19. **purpose**

# %%
# 1 - additions: The # of added LOC by a PR
# 2 - deletions The # of deleted LOC by a PR
# 3 - prSize: The total number of added and deleted LOC by a PR (additions + deletions)
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['additions', 'deletions', 'prSize', 'pr_id'], errors='ignore')

# Get the sums of the columns we are interested in
pr_commit_LOC = (pr_commit_details.groupby(['pr_id'])
                                  .sum(['additions', 'deletions', 'changes'])
                                  .reset_index())

# Rename the sum columns to what we want
pr_commit_LOC = (pr_commit_LOC.rename(columns={'changes': 'prSize'}))

# Drop the extraneous columns
pr_commit_LOC = pr_commit_LOC.drop(columns=['commit_stats_total', 'commit_stats_additions', 'commit_stats_deletions'])

# Merge the Dataframes with a left join
metrics = pd.merge(metrics, pr_commit_LOC, left_on='id', right_on='pr_id', how='left')

# Garbage collect the temporary Dataframe
pr_commit_LOC = None

# Fill N/A values with defaults
metrics['additions'] = metrics['additions'].fillna(0).astype(int)
metrics['deletions'] = metrics['deletions'].fillna(0).astype(int)
metrics['prSize'] = metrics['prSize'].fillna(0).astype(int)

# Drop the 'pr_id' column that was left as an artifact of the merge
metrics = metrics.drop(columns=['pr_id'], errors='ignore')

# %%
# 4 - purpose: The purpose of a PR, i.e., bug, document, and feature. Simple keyword search in the title/body ('fix', 'bug', 'doc', …).
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['purpose'], errors='ignore')

# Make a copy of the PR Task Type Dataframe and Drop unneeded columns
pr_task = pr_task_type.copy().drop(columns=['agent', 'title', 'reason', 'confidence'], errors='ignore')

# Group by ID and get the First Record
pr_task = pr_task.groupby(['id']).first()

# Rename the column to what we want to keep
pr_task = pr_task.rename(columns={'type': 'purpose'})

# Merge the Dataframes with a left join
metrics = pd.merge(metrics, pr_task, left_on='id', right_on='id', how='left')

# Garbage Collect the temporary Dataframe
pr_task = None

# Fill N/A values with defaults
metrics['purpose'] = metrics['purpose'].fillna('other')

#Check that the purpose = either of the three options; Bug, Feature, Document

# %%
# 5 - changedFiles: The # of files changed by a PR
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['changedFiles', 'pr_id'], errors='ignore')

# Count the number of Files changed and change the column name to what we want
pr_files_changed = (pr_commit_details.groupby(['pr_id', 'filename'])
                                     .size()
                                     .groupby(['pr_id'])
                                     .size()
                                     .reset_index(name='changedFiles'))

# Merge the Dataframes with a left join
metrics = pd.merge(metrics, pr_files_changed, left_on='id', right_on='pr_id', how='left')

# Garbage Collect the temporary Dataframe
pr_files_changed = None

# Fill N/A values with defaults
metrics['changedFiles'] = metrics['changedFiles'].fillna(0).astype(int)

# Drop the 'pr_id' column that was left as an artifact of the merge
metrics = metrics.drop(columns=['pr_id'], errors='ignore')

# %%
# 6 - commitsTotalCount: The # of commits involved in a PR
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['commitsTotalCount', 'pr_id'], errors='ignore')

# Count the number of Commits for the Pull Request, name the column what we want.
pr_commits_count = pr_commits.groupby(['pr_id']).size().reset_index(name='commitsTotalCount')

# Merge the Dataframes using a left join
metrics = pd.merge(metrics, pr_commits_count, left_on='id', right_on='pr_id', how='left')

# Garbage Collect the temporary Dataframe
pr_commits_count = None

# Fill N/A values with defaults
metrics['commitsTotalCount'] = metrics['commitsTotalCount'].fillna(0).astype(int)

# Drop the 'pr_id' column that was left as an artifact of the merge
metrics = metrics.drop(columns=['pr_id'], errors='ignore')

# %%
# 7 - bodyLength The length of a PR description (in characters)
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['bodyLength'], errors='ignore')

# Get the Length of the Body of the Pull Request
metrics['bodyLength'] = metrics['body'].str.len()

# %%
# 8 - prExperience: The # of prior PRs that were submitted by the PR author (author’s prior PR count).
#     Query the author’s PR history in the same repo and count PRs created before the current one.
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['prExperience'], errors='ignore')

# TODO: Figure out how to do this
metrics['prExperience'] = 0

# %%
# 9 - isMember: Whether or not the author is a member or outside collaborator (True/False)
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['isMember'], errors='ignore')

# TODO: Figure out how to tell if a user is a member
metrics['isMember'] = False

# %%
# 10 - commentsTotalCount: The # of comments left on a PR
# Make sure we don't crash because the columns already exist (rentrant code)
metrics.drop(columns=['commentsTotalCount', 'pr_id'], errors='ignore', inplace=True)

# Count the number of Comments for the Pull Request, name the column what we want.
pr_comments_count = pr_comments.groupby(['pr_id']).size().reset_index(name='commentsTotalCount')

# Merge the Dataframes using a left join
metrics = pd.merge(metrics, pr_comments_count, left_on='id', right_on='pr_id', how='left')

# Garbage Collect the temporary Dataframe
pr_comments_count = None

# Fill N/A values with defaults
metrics['commentsTotalCount'] = metrics['commentsTotalCount'].fillna(0).astype(int)

# Drop the 'pr_id' column that was left as an artifact of the merge
metrics.drop(columns=['pr_id'], errors='ignore', inplace=True)

# %%
# 11 - authorComments: The # of comments left by the PR author
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['authorComments', 'pr_id'], errors='ignore')

# Filter comments to only include those made by the PR author
# Need to merge with metrics to get the author_id for each pr_comment
author_comments = pd.merge(pr_comments, metrics[['id', 'user_id']], left_on='pr_id', right_on='id', how='left')
author_comments = author_comments[author_comments['user_id_x'] == author_comments['user_id_y']]

# Count the number of author comments per pull request
author_comments_count = author_comments.groupby(['pr_id']).size().reset_index(name='authorComments')

# Merge the Dataframes using a left join
metrics = pd.merge(metrics, author_comments_count, left_on='id', right_on='pr_id', how='left')

# Garbage Collect the temporary Dataframes
author_comments = None
author_comments_count = None

# Fill N/A values with defaults
metrics['authorComments'] = metrics['authorComments'].fillna(0).astype(int)

# Drop the 'pr_id' column that was left as an artifact of the merge
metrics = metrics.drop(columns=['pr_id'], errors='ignore')

# %%
# 12 - reviewersComments: The # of comments left by the reviewers who participate in the discussion
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['reviewersComments', 'pr_id'], errors='ignore')

# Filter comments to exclude those made by the PR author
# Need to merge with metrics to get the author_id for each pr_comment
reviewer_comments = pd.merge(pr_comments, metrics[['id', 'user_id']], left_on='pr_id', right_on='id', how='left')
reviewer_comments = reviewer_comments[reviewer_comments['user_id_x'] != reviewer_comments['user_id_y']]

# Count the number of reviewer comments per pull request
reviewer_comments_count = reviewer_comments.groupby(['pr_id']).size().reset_index(name='reviewersComments')

# Merge the Dataframes using a left join
metrics = pd.merge(metrics, reviewer_comments_count, left_on='id', right_on='pr_id', how='left')

# Garbage Collect the temporary Dataframes
reviewer_comments = None
reviewer_comments_count = None

# Fill N/A values with defaults
metrics['reviewersComments'] = metrics['reviewersComments'].fillna(0).astype(int)

# Drop the 'pr_id' column that was left as an artifact of the merge
metrics = metrics.drop(columns=['pr_id'], errors='ignore')

# %%
# 13 - reviewersTotalCount: The # of developers who participate in the discussion.
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['reviewersTotalCount', 'pr_id'], errors='ignore')

# Extract user_id from the nested 'user' column in pr_review_comments
pr_review_comments['user_id_from_user'] = pr_review_comments['user'].apply(lambda x: x.get('id') if isinstance(x, dict) else None)

# Extract user_id from the nested 'user' column in pr_reviews
pr_reviews['user_id_from_user'] = pr_reviews['user'].apply(lambda x: x.get('id') if isinstance(x, dict) else None)

# Get author_id from metrics for merging
metrics['author_id_from_author'] = metrics['user'].apply(lambda x: x.get('id') if isinstance(x, dict) else None)


# Get unique reviewer IDs from review comments, excluding the author
reviewer_comments_users = pd.merge(pr_review_comments, metrics[['id', 'author_id_from_author']], left_on='pull_request_review_id', right_on='id', how='left')
reviewer_comments_users = reviewer_comments_users[reviewer_comments_users['user_id_from_user'] != reviewer_comments_users['author_id_from_author']]
reviewer_comments_users = reviewer_comments_users.groupby(['pull_request_review_id'])['user_id_from_user'].nunique().reset_index(name='reviewer_commenters')


# Get unique reviewer IDs from reviews, excluding the author
review_users = pd.merge(pr_reviews, metrics[['id', 'author_id_from_author']], left_on='pr_id', right_on='id', how='left')
review_users = review_users[review_users['user_id_from_user'] != review_users['author_id_from_author']]
review_users = review_users.groupby(['pr_id'])['user_id_from_user'].nunique().reset_index(name='reviewers')

# Merge the two dataframes to get unique users from both sources
reviewers_total = pd.merge(reviewer_comments_users, review_users, left_on='pull_request_review_id', right_on='pr_id', how='outer').fillna(0)

# Calculate the total number of unique reviewers
reviewers_total['reviewersTotalCount'] = reviewers_total['reviewer_commenters'] + reviewers_total['reviewers']
reviewers_total = reviewers_total.drop(columns=['reviewer_commenters', 'reviewers'])

# Merge the Dataframes using a left join
metrics = pd.merge(metrics, reviewers_total, left_on='id', right_on='pull_request_review_id', how='left')

# Garbage Collect temporary dataframes
reviewer_comments_users = None
review_users = None
reviewers_total = None

# Fill N/A values with defaults
metrics['reviewersTotalCount'] = metrics['reviewersTotalCount'].fillna(0).astype(int)

# Drop the 'pr_id' column that was left as an artifact of the merge
metrics = metrics.drop(columns=['pr_id'], errors='ignore')

# Drop the temporary user_id and author_id columns
pr_review_comments = pr_review_comments.drop(columns=['user_id_from_user'], errors='ignore')
pr_reviews = pr_reviews.drop(columns=['user_id_from_user'], errors='ignore')
metrics = metrics.drop(columns=['author_id_from_author'], errors='ignore')

# %%
# 14 - repoAge: Time interval between the repository creation time and PR creation time in days.
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['repoAge'], errors='ignore')

# Copy the Repository dataframe and remove the unnecessary columns
repos_temp = (repos.copy()
                   .drop(columns=['license', 'full_name', 'language', 'forks', 'stars'], errors='ignore')
                   .rename(columns={'id': 'repo_id'}))

# Drop the now unnecessary URL column
repos_temp = repos_temp.drop(columns=['url'], errors='ignore')

# Merge the Dataframes using a left join
metrics = pd.merge(metrics, repos_temp, left_on='repo_id', right_on='repo_id', how='left')

# Garbage Collect the temporary dataframe
repos_temp = None

# Drop from Metrics any Repo without a repo created date
metrics = metrics.dropna(subset=['repo_created_at'])

# Calculate the Repo Age in Days (created_at - repo_created_at), handling potential None values
metrics['repoAge'] = (metrics['created_at'].dt.days - metrics['repo_created_at'].dt.days)

# Drop the unnecessary Repo Created At column
metrics = metrics.drop(columns=['repo_created_at'], errors='ignore')

# Fill N/A values with defaults
metrics['repoAge'] = metrics['repoAge'].fillna(0).astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2945174243.py in <cell line: 0>()
#      18
#      19 # Drop from Metrics any Repo without a repo created date
# ---> 20 metrics = metrics.dropna(subset=['repo_created_at'])
#      21
#      22 # Calculate the Repo Age in Days (created_at - repo_created_at), handling potential None values
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#
# KeyError: ['repo_created_at']

# %%
# 15 - repoLanguage: The repository language that a PR belongs to (top language)
# 16 - forkCount: The # of forks that a repository has
# 17 - stargazerCount: The # of stargazers that a repository has.
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['repoLanguage', 'forkCount', 'stargazerCount'], errors='ignore')

repos = (repository.copy()
                   .drop(columns=['license', 'repo_url', 'html_url', 'full_name'], errors='ignore')
                   .rename(columns={'id': 'repo_id', 'language': 'repoLanguage', 'forks': 'forkCount', 'stars': 'stargazerCount'}))

# Group by ID and get the First Record
repos = repos.groupby(['repo_id']).first().reset_index() # Add reset_index() to make repo_id a column again

# Merge the Dataframes using a left join
metrics = pd.merge(metrics, repos, left_on='repo_id', right_on='repo_id', how='left')

# Garbage Collect the temporary Dataframe
repos = None

# Fill N/A values with defaults
metrics['repoLanguage'] = metrics['repoLanguage'].fillna('other')
metrics['forkCount'] = metrics['forkCount'].fillna(0).astype(int)
metrics['stargazerCount'] = metrics['stargazerCount'].fillna(0).astype(int)

# %%
# 18 - state: State of the pull request (MERGED or CLOSED).
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['isMerged'], errors='ignore')

metrics['isMerged'] = metrics['merged_at'].apply(lambda x: 0 if x is None else 1)

# %%
# 19 - reviewTime: Time taken to review the PR (in hours, floating point, no rounding).
# Make sure we don't crash because the columns already exist (rentrant code)
metrics = metrics.drop(columns=['reviewTime'], errors='ignore')

# Calculate review time in hours, handling potential NaT values
metrics['reviewTime'] = ((metrics['closed_at']dt.total_seconds - metrics['created_at'].dt.total_seconds) / 3600).astype(float)

# Fill N/A values with defaults (e.g., for open PRs)
metrics['reviewTime'] = metrics['reviewTime'].fillna(0)

# %%
csv_order = ['repoLanguage',
'forkCount',
'stargazerCount',
'repoAge',
'state',
'deletions',
'additions',
'changedFiles',
'commentsTotalCount',
'commitsTotalCount',
'prExperience',
'isMember',
'authorComments',
'reviewersComments',
'reviewersTotalCount',
'bodyLength',
'prSize',
'reviewTime',
'purpose']

metrics = metrics.loc[:, csv_order]
metrics = metrics[csv_order]
display(metrics.columns)

# %% [markdown]
# # **Fourth**, Bot detection and filtering employed the methodology of Golzadeh et al. (2022)
#
# simple “bot” username suffix check with a comprehensive, manually verified list of 527 bot accounts
# * groundtruthbots.csv - a list of bots from Golzadeh et al.

# %% [markdown]
# # **Fifth**, Adoption Trend (RQ1)
#
# * Counted occurrences of each marker tag; copilot:summary was the most frequent (13 231 instances).
# * Visualised cumulative PRs over time (Fig. 3) and proportion of PRs per repository (Fig. 4).

# %% [markdown]
# # **Sixth**, Causal Inference (RQ2)
#
# ### Propensity‑Score Estimation
# Logistic regression (treatment = Copilot usage) on the 17 covariates.
# Estimated each PR’s probability of receiving the treatment (ps).
# ### Weight Construction
# Inverse‑probability weights: 1/ps for treated, 1/(1‑ps) for control.
# ### Entropy Balancing
# Applied the entropy‑balancing algorithm (equivalent to R’s ebalance) to adjust the raw weights so that the weighted means of all covariates matched exactly between groups.
# After balancing, absolute mean differences for every covariate were ≤ 0.10 (Fig. 2).
# ### Outcome Regression
# * Review time (continuous): weighted ordinary least squares (lm analogue) with only the treatment indicator. The coefficient gave the Average Treatment Effect on the Treated (ATT) of ‑19.3 h (p ≈ 1.6 × 10⁻¹⁷).
# * Merge outcome (binary): weighted logistic regression (glm with logit link). The exponentiated treatment coefficient yielded an odds ratio of 1.57 (95 % CI [1.35, 1.84], p < 0.001).
# These two models answer RQ2.1 (review‑time reduction) and RQ2.2 (higher merge likelihood).

# %% [markdown]
# # The R Scripts
# The main difference between PMW_merge.R and PMW_review.R is:
#
# * PMW_merge.R includes the column isMerged, which indicates whether each pull request was merged (state == "MERGED"). This column is added to the modeling data and used in the analysis.
# * PMW_review.R does not include the isMerged column in its modeling data; it focuses only on review-related metrics.
# * Otherwise, both scripts process the same input data, use similar covariates, and prepare for causal inference analysis. The inclusion of isMerged in PMW_merge.R allows for analysis related to PR merge status, while PMW_review.R is focused on review characteristics.
